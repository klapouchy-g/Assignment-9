# %% [markdown]
# # Short report on *The Orville*
#
#
# ## Synopsis
# *The Orville* is an American science fiction comedy drama television series created by **Seth MacFarlane**, who also stars as the protagonist *Ed Mercer*, an officer in the Planetary Union's line of exploratory space vessels in the 25th century. It was inspired primarily by the original Star Trek and Next Generation programs, and the series pays homage to both. The series also draws inspiration from the Star Wars franchise. Produced by **Fuzzy Door Productions** and **20th Television**, it follows the crew of the starship *USS Orville* on their episodic adventures, as well as a serialized story which develops over the length of the series. According to **MacFarlane**, the series and the starship are named after the aviation pioneer Orville Wright.
#
# ## Premiere
# *The Orville* premiered on September 10, 2017, and ran for two seasons on **Fox** and became available on streaming service Hulu the following day, followed by a third season exclusively on **Hulu**. After generally unfavorable reviews for season 1, season 2 onwards received critical acclaim. The show had relatively successful ratings on **Fox**, becoming the broadcaster's highest-rated Thursday show as well as **Fox's** "most-viewed debut drama" since 2015.
#
# ## Cast and Crew
# The series features an ensemble cast including **Scott Grimes** as Lieutenant Gordon Mallory, **Adrianne Palicki** as Captain Kelly Grayson, **Peter Macon** as Lieutenant Commander Bortus, **Norm MacDonald** as Dr. Zaander, and **Halston Sage** as Ensign Alara Kitan. The show's production team includes executive producers and writers who have contributed to its distinctive blend of humor and dramatic storytelling.
#
# ![The Orville logo featuring the starship USS Orville with the series title in bold lettering against a deep space background](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/The_Orville_logo.svg/3840px-The_Orville_logo.svg.png)

# %% [markdown]
# ## Episode Ratings
#
# The table below summarises the IMDb ratings for all episodes across all three seasons of *The Orville*.

# %%
import pandas as pd

data = [
    # Season 1
    (1,  1,  "Old Wounds",                              7.8),
    (1,  2,  "Command Performance",                     7.8),
    (1,  3,  "About a Girl",                            8.4),
    (1,  4,  "If the Stars Should Appear",              8.1),
    (1,  5,  "Pria",                                    8.2),
    (1,  6,  "Krill",                                   8.4),
    (1,  7,  "Majority Rule",                           8.3),
    (1,  8,  "Into the Fold",                           7.8),
    (1,  9,  "Cupid's Dagger",                          7.5),
    (1, 10,  "Firestorm",                               8.1),
    (1, 11,  "New Dimensions",                          8.0),
    (1, 12,  "Mad Idolatry",                            8.3),
    # Season 2
    (2,  1,  "Ja'loja",                                 7.4),
    (2,  2,  "Primal Urges",                            7.8),
    (2,  3,  "Home",                                    8.4),
    (2,  4,  "Nothing Left on Earth Excepting Fishes",  8.0),
    (2,  5,  "All the World is Birthday Cake",          7.9),
    (2,  6,  "A Happy Refrain",                         8.6),
    (2,  7,  "Deflectors",                              7.9),
    (2,  8,  "Identity, Part I",                        8.8),
    (2,  9,  "Identity, Part II",                       8.9),
    (2, 10,  "Blood of Patriots",                       7.6),
    (2, 11,  "Lasting Impressions",                     8.4),
    (2, 12,  "Sanctuary",                               8.2),
    (2, 13,  "Tomorrow, and Tomorrow, and Tomorrow",    8.1),
    (2, 14,  "The Road Not Taken",                      8.2),
    # Season 3 (New Horizons – Hulu)
    (3,  1,  "Electric Sheep",                          8.2),
    (3,  2,  "Shadow Realms",                           8.1),
    (3,  3,  "Mortality Paradox",                       8.1),
    (3,  4,  "Gently Falling Rain",                     8.4),
    (3,  5,  "A Tale of Two Topas",                     9.1),
    (3,  6,  "Twice in a Lifetime",                     9.0),
    (3,  7,  "From Unknown Graves",                     8.3),
    (3,  8,  "Midnight Blue",                           8.6),
    (3,  9,  "The One That Got Away",                   8.1),
    (3, 10,  "Future Unknown",                          8.6),
    (3, 11,  "A Little More Perfect",                   8.5),
]

df = pd.DataFrame(data, columns=["Season", "Episode", "Title", "IMDb Rating"])
df["Season"] = df["Season"].apply(lambda s: f"Season {s}")

pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
print(df.to_string(index=False))
# Out:
#   Season  Episode                                  Title  IMDb Rating
# Season 1        1                             Old Wounds          7.8
# Season 1        2                    Command Performance          7.8
# Season 1        3                           About a Girl          8.4
# Season 1        4             If the Stars Should Appear          8.1
# Season 1        5                                   Pria          8.2
# Season 1        6                                  Krill          8.4
# Season 1        7                          Majority Rule          8.3
# Season 1        8                          Into the Fold          7.8
# Season 1        9                         Cupid's Dagger          7.5
# Season 1       10                              Firestorm          8.1
# Season 1       11                         New Dimensions          8.0
# Season 1       12                           Mad Idolatry          8.3
# Season 2        1                                Ja'loja          7.4
# Season 2        2                           Primal Urges          7.8
# Season 2        3                                   Home          8.4
# Season 2        4 Nothing Left on Earth Excepting Fishes          8.0
# Season 2        5         All the World is Birthday Cake          7.9
# Season 2        6                        A Happy Refrain          8.6
# Season 2        7                             Deflectors          7.9
# Season 2        8                       Identity, Part I          8.8
# Season 2        9                      Identity, Part II          8.9
# Season 2       10                      Blood of Patriots          7.6
# Season 2       11                    Lasting Impressions          8.4
# Season 2       12                              Sanctuary          8.2
# Season 2       13   Tomorrow, and Tomorrow, and Tomorrow          8.1
# Season 2       14                     The Road Not Taken          8.2
# Season 3        1                         Electric Sheep          8.2
# Season 3        2                          Shadow Realms          8.1
# Season 3        3                      Mortality Paradox          8.1
# Season 3        4                    Gently Falling Rain          8.4
# Season 3        5                    A Tale of Two Topas          9.1
# Season 3        6                    Twice in a Lifetime          9.0
# Season 3        7                    From Unknown Graves          8.3
# Season 3        8                          Midnight Blue          8.6
# Season 3        9                  The One That Got Away          8.1
# Season 3       10                         Future Unknown          8.6
# Season 3       11                  A Little More Perfect          8.5
